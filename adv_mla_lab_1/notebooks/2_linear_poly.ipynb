# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import packages
import pandas as pd
import numpy as np
from joblib import dump

# %%
X_train = pd.read_csv('../data/processed/X_train.csv')
X_val   = pd.read_csv('../data/processed/X_val.csv'  )
X_test  = pd.read_csv('../data/processed/X_test.csv' )
y_train = pd.read_csv('../data/processed/y_train.csv')
y_val   = pd.read_csv('../data/processed/y_val.csv'  )
y_test  = pd.read_csv('../data/processed/y_test.csv' )

# %%
# Apply Polynomial Transformation
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(2)

# %%
X_train = poly.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.        ,  1.        ,  0.        , ...,  0.36061773,
#          0.0563269 ,  0.00879801],
#        [ 1.        ,  0.        ,  1.        , ...,  0.27996505,
#          0.48589927,  0.84331276],
#        [ 1.        ,  0.        ,  1.        , ...,  0.2545177 ,
#          0.46329043,  0.84331276],
#        ...,
#        [ 1.        ,  0.        ,  0.        , ...,  1.43019507,
#         -1.09822664,  0.84331276],
#        [ 1.        ,  1.        ,  1.        , ...,  1.66906948,
#         -1.18640111,  0.84331276],
#        [ 1.        ,  1.        ,  0.        , ...,  1.50978722,
#         -0.11525245,  0.00879801]])

# %%
X_train.shape
# Out:
# (32000, 45)

# %%
X_val = poly.transform(X_val)
X_test = poly.transform(X_test)

# %%
# Train a linear regression model
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from joblib import dump

dump(reg,  '../models/linear_poly_2.joblib')
# Out:
# ['../models/linear_poly_2.joblib']

# %%
# Save the prediction from this model
y_train_preds = reg.predict(X_train)
y_val_preds = reg.predict(X_val)

# %%
from sklearn.metrics import root_mean_squared_error as rmse
from sklearn.metrics import mean_absolute_error as mae

# %%
print(rmse(y_train_preds, y_train))
print(mae(y_train_preds, y_train))
# Out:
# 5885.9498206635635
# 3909.957023563625

# %%
# Testing set
y_test_preds = reg.predict(X_test)
print(rmse(y_test_preds, y_test))
print(mae(y_test_preds, y_test))
# Out:
# 5979.25889992347
# 4033.2538660158
